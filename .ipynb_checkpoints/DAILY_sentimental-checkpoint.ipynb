# %%
# Import
import json
import math
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
# from fastai.structured import add_datepart

# Linear Regression
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# # Data Collecting

# %%
# Config
symbl = 'AAPL'
apiKey = 'MSXSR0YHC991CZN6'

# Fetch Historical Data
df = pd.read_csv('https://www.alphavantage.co/query?datatype=csv&function=TIME_SERIES_DAILY&symbol=' + symbl + '&outputsize=full&apikey=' + apiKey)

# Setting index as date
df['timestamp'] = pd.to_datetime(df.timestamp, format='%Y-%m-%d')
df.index = df['timestamp']

# %%
# Write dataframe to access locally
df.to_csv("daily_AAPL.csv", sep='\t', index=False)

# %% [markdown]
# # Data Overview

# %%
# Get general statistics
df.describe()
# Out:
#               open         high          low        close        volume
# count  5031.000000  5031.000000  5031.000000  5031.000000  5.031000e+03
# mean    170.531490   172.387633   168.498200   170.481335  1.158857e+08
# std     160.601243   161.878975   159.062451   160.489462  9.850473e+07
# min      12.990000    13.190000    12.720000    13.120000  9.835000e+06
# 25%      55.365000    56.924000    54.515000    55.637500  4.884080e+07
# 50%     117.950000   119.400000   116.680000   118.310000  8.870960e+07
# 75%     202.480000   204.550000   200.817500   202.740000  1.523837e+08
# max     702.410000   705.070000   699.570000   702.100000  1.855410e+09

# %%
# Get data types
df.dtypes
# Out:
# timestamp    datetime64[ns]
# open                float64
# high                float64
# low                 float64
# close               float64
# volume                int64
# dtype: object

# %%
# Check top 10 rows
df.head(10)
# Out:
#             timestamp    open    high     low   close    volume
# timestamp
# 2019-10-15 2019-10-15  236.39  237.64  234.88  235.32  19012889
# 2019-10-14 2019-10-14  234.90  238.13  234.67  235.87  24106900
# 2019-10-11 2019-10-11  232.95  237.64  232.31  236.21  41698900
# 2019-10-10 2019-10-10  227.93  230.44  227.30  230.09  28253400
# 2019-10-09 2019-10-09  227.03  227.79  225.64  227.03  18692600
# 2019-10-08 2019-10-08  225.82  228.06  224.33  224.40  27955000
# 2019-10-07 2019-10-07  226.27  229.93  225.84  227.06  30576500
# 2019-10-04 2019-10-04  225.64  227.49  223.89  227.01  34619700
# 2019-10-03 2019-10-03  218.43  220.96  215.13  220.82  28606500
# 2019-10-02 2019-10-02  223.06  223.58  217.93  218.96  34612300

# %%
# Check last 10 rows
df.tail(10)
# Out:
#             timestamp     open     high      low   close     volume
# timestamp
# 1999-10-29 1999-10-29  78.8130  81.0630  78.8130  80.125  130762800
# 1999-10-28 1999-10-28  77.0630  79.0000  76.0630  77.875  126022400
# 1999-10-27 1999-10-27  74.3750  76.6250  73.4380  76.375  110768000
# 1999-10-26 1999-10-26  74.9380  75.4992  73.3130  75.063   90358800
# 1999-10-25 1999-10-25  74.2500  76.1250  73.7485  74.500   81648000
# 1999-10-22 1999-10-22  77.1250  77.2500  73.3750  73.938  104876800
# 1999-10-21 1999-10-21  72.5627  77.0630  72.3750  76.125  198363200
# 1999-10-20 1999-10-20  70.0000  75.2500  70.0000  75.125  270351200
# 1999-10-19 1999-10-19  71.6250  75.0000  68.4380  68.500  255645600
# 1999-10-18 1999-10-18  73.8750  74.2500  71.1250  73.250  194101600

# %% [markdown]
# # Convert closing price to trading action

# %%
# Expected Return
# expectedReturn = 0 # Long if the stock price stays the same or increases
expectedReturn = 0.025 # Long if the stock price increases by 2.5%

df['prev_close'] = df['close'].shift(-1)

df['action'] = np.nan 

for i, row in df.iterrows():
    realReturn = (df.loc[i, 'close'] / df.loc[i, 'prev_close']) - 1
    df.loc[i, 'action'] = 1 if (realReturn >= expectedReturn) else 0 # 1 = Long / 0 = Short


df.head(10)
# Out:
#             timestamp    open    high     low   close    volume  prev_close  \
# timestamp
# 2019-10-15 2019-10-15  236.39  237.64  234.88  235.32  19012889      235.87
# 2019-10-14 2019-10-14  234.90  238.13  234.67  235.87  24106900      236.21
# 2019-10-11 2019-10-11  232.95  237.64  232.31  236.21  41698900      230.09
# 2019-10-10 2019-10-10  227.93  230.44  227.30  230.09  28253400      227.03
# 2019-10-09 2019-10-09  227.03  227.79  225.64  227.03  18692600      224.40
# 2019-10-08 2019-10-08  225.82  228.06  224.33  224.40  27955000      227.06
# 2019-10-07 2019-10-07  226.27  229.93  225.84  227.06  30576500      227.01
# 2019-10-04 2019-10-04  225.64  227.49  223.89  227.01  34619700      220.82
# 2019-10-03 2019-10-03  218.43  220.96  215.13  220.82  28606500      218.96
# 2019-10-02 2019-10-02  223.06  223.58  217.93  218.96  34612300      224.59
#
#             action
# timestamp
# 2019-10-15     0.0
# 2019-10-14     0.0
# 2019-10-11     1.0
# 2019-10-10     0.0
# 2019-10-09     0.0
# 2019-10-08     0.0
# 2019-10-07     0.0
# 2019-10-04     1.0
# 2019-10-03     0.0
# 2019-10-02     0.0

# %% [markdown]
# # Preparing data to merge with news data

# %%
df.drop(df.index[:10], inplace=True)
len(df)
df
# Out:
#             timestamp      open      high       low    close     volume  \
# timestamp
# 2019-10-01 2019-10-01  225.0700  228.2200  224.2000  224.590   34805800
# 2019-09-30 2019-09-30  220.9000  224.5800  220.7900  223.970   25977400
# 2019-09-27 2019-09-27  220.5400  220.9600  217.2800  218.820   25352000
# 2019-09-26 2019-09-26  220.0000  220.9400  218.8300  219.890   18833500
# 2019-09-25 2019-09-25  218.5500  221.5000  217.1400  221.030   21903400
# 2019-09-24 2019-09-24  221.0300  222.4900  217.1900  217.680   31190800
# 2019-09-23 2019-09-23  218.9500  219.8400  217.6500  218.720   19165500
# 2019-09-20 2019-09-20  221.3800  222.5600  217.4700  217.730   55413100
# 2019-09-19 2019-09-19  222.0100  223.7600  220.3700  220.960   22060600
# 2019-09-18 2019-09-18  221.0600  222.8500  219.4400  222.770   25340000
# 2019-09-17 2019-09-17  219.9600  220.8200  219.1200  220.700   18318700
# 2019-09-16 2019-09-16  217.7300  220.1300  217.5600  219.900   21158100
# 2019-09-13 2019-09-13  220.0000  220.7900  217.0200  218.750   39763300
# 2019-09-12 2019-09-12  224.8000  226.4200  222.8600  223.090   32226700
# 2019-09-11 2019-09-11  218.0700  223.7100  217.7300  223.590   44289600
# 2019-09-10 2019-09-10  213.8600  216.7800  211.7100  216.700   31777900
# 2019-09-09 2019-09-09  214.8400  216.4400  211.0700  214.170   27309400
# 2019-09-06 2019-09-06  214.0500  214.4200  212.5100  213.260   19362300
# 2019-09-05 2019-09-05  212.0000  213.9700  211.5100  213.280   23913700
# 2019-09-04 2019-09-04  208.3900  209.4800  207.3200  209.190   19188100
# 2019-09-03 2019-09-03  206.4300  206.9800  204.2200  205.700   20023000
# 2000-01-04     111.938     0.0
# 2000-01-03     102.813     1.0

# %% [markdown]
# # Import News data

# %%
def open_json(year, month):
    "Save as pandas dataframe"
    file_str = 'data/jsons/' + str(year) + '-' + '{:02}'.format(month) + '.json'
    with open(file_str) as data_file:    
        NYTimes_data = json.load(data_file)
    
    date_list = []
    df = pd.DataFrame()  
    df['News'] = None
    

    for i in range(len(NYTimes_data["response"]["docs"][:])):
        if NYTimes_data["response"]["docs"][i]["pub_date"][:10] not in df.index:
            df.loc[NYTimes_data["response"]["docs"][i]["pub_date"][:10]] = NYTimes_data["response"]["docs"][:][i]['headline']['main']
        else:
            df.loc[NYTimes_data["response"]["docs"][i]["pub_date"][:10]] = df.loc[NYTimes_data["response"]["docs"][i]["pub_date"][:10]].values + NYTimes_data["response"]["docs"][:][i]['headline']['main']
    
    df.index = pd.to_datetime(df.index, format='%Y-%m-%d')
    df.sort_index(inplace=True)
    
    return df

# %%
open_json(2000,1)
# Out:
#                                                          News
# 2000-01-01  A Generation's Anthem: 'Smells Like Teen Press...
# 2000-01-02  Q & A/Christopher Wigren; Making a Job of Pres...
# 2000-01-03  Looking Back to Move ForwardA Touch of Spring ...
# 2000-01-04  No Bones About ItCarroll and Rhodes Are Out, a...
# 2000-01-05  Climate ControlWith Mild Winter, Snow Business...
# 2000-01-06  Calling All UnitsLarry Bearnarth, 58, the Best...
# 2000-01-07  Nature in a Flick of the EyeDefense Chief Pled...
# 2000-01-08  Florida Passes Bill to Quicken Execution PaceB...
# 2000-01-09  Despite Expectations, Magic Is Doing WellWriti...
# 2000-01-10  International Custody BattlePaid Notice: Death...
# 2000-01-11  Plagued by PovertyTHE MARKETS: CURRENCIESBring...
# 2000-01-12  When Things Fall ApartNot-So-Fickle Pinot Noir...
# 2000-01-13  Turning Some Things Old into Something NewSupr...
# 2000-01-14  The Right to Remain ResilientIn the Very Dista...
# 2000-01-15  Winter in New York: Something's Missing; Absen...
# 2000-01-16  It's Not Too Late or Irrational For Mr. Forbes...
# 2000-01-17  E.P.A. Announces New Rules On Genetically Alte...
# 2000-01-18  All Creatures Microscopically SmallAs Johnson ...
# 2000-01-19  At the Heights of ConflictQUOTATION OF THE DAY...
# 2000-01-20  Death Shatters Families At Time Full of Promis...
# 2000-01-21  The Sundance KidsMosley Likes Chances In Highe...
# 2000-01-22  Canada Kills Subsidy Plan for 6 N.H.L. TeamsMi...
# 2000-01-23  The Rapidly Sinking Spirit Of a Harbor Dredgin...
# 2000-01-24  Iowa's Primary's ColorsForbes Focuses on Abort...
# 2000-01-25  After Fatal Campus Fire, a Yearning for Normal...
# 2000-01-26  Plagued by WarfareShocking the Culture: Examin...
# 2000-01-27  Warning Signs for Dangerous TimesChina Lists C...
# 2000-01-28  Words of Deep MeaningWhere Winter's a Wonder a...
# 2000-01-29  Paid Notice: Deaths  KAPLAN, NETTIEPaid Notice...
# 2000-01-30  Q&A/Teresa C. Cusano; Keeping Her Eye On Long-...
# 2000-01-31  Going, But Not ForgottenJohn Gaherin, 85, Nego...

# %% [markdown]
# # Merge technical stock data with news

# %%
def merge_news_price(df):
    all_news = pd.DataFrame()
    for i in range(2000, 2020):
        for j in range(1, 13):
            try:
                temp = open_json(i, j)
                all_news = all_news.append(temp)
                print("Completed {}-{}".format(i, j))
            except:
                pass
    print(all_news)   
#     all_news = pd.concat([df, all_news],join='inner', axis=1)
    
    return all_news

# %%
data = merge_news_price(df)
# Out:
# Completed 2000-1
# Completed 2000-2
# Completed 2000-3
# Completed 2000-4
# Completed 2000-5
# Completed 2000-6
# Completed 2000-7
# Completed 2000-8
# Completed 2000-9
# Completed 2000-10
# Completed 2000-11
# Completed 2000-12
# Completed 2001-1
# Completed 2001-2
# Completed 2001-3
# Completed 2001-4
# Completed 2001-5
# Completed 2001-6
# Completed 2001-7
# Completed 2001-8
# Completed 2001-9
# Completed 2001-10
# Completed 2001-11
# Completed 2001-12
# Completed 2002-1
# Completed 2002-2
# Completed 2002-3
# Completed 2002-4
# Completed 2002-5
# Completed 2002-6
# Completed 2002-7
# Completed 2002-8
# Completed 2002-9
# Completed 2002-10
# Completed 2002-11
# Completed 2002-12
# Completed 2003-1
# Completed 2003-2
# Completed 2003-3
# Completed 2003-4
# Completed 2003-5
# Completed 2003-6
# Completed 2003-7
# Completed 2003-8
# Completed 2003-9
# Completed 2003-10
# Completed 2003-11
# Completed 2003-12
# Completed 2004-1
# Completed 2004-2
# Completed 2004-3
# Completed 2004-4
# Completed 2004-5
# Completed 2004-6
# Completed 2004-7
# Completed 2004-8
# Completed 2004-9
# Completed 2004-10
# Completed 2004-11
# Completed 2004-12
# Completed 2005-1
# Completed 2005-2
# Completed 2005-3
# Completed 2005-4
# Completed 2005-5
# Completed 2005-6
# Completed 2005-7
# Completed 2005-8
# Completed 2005-9
# Completed 2005-10
# Completed 2005-11
# Completed 2005-12
# Completed 2007-12
# Completed 2008-1
# Completed 2008-2
# Completed 2008-3
# Completed 2008-4
# Completed 2008-5
# Completed 2008-6
# Completed 2008-7
# Completed 2008-8
# Completed 2008-9
# Completed 2008-10
# Completed 2009-1
# Completed 2009-2
# Completed 2009-4
# Completed 2009-7
# Completed 2009-8
# Completed 2009-9
# Completed 2009-10
# Completed 2009-11
# Completed 2009-12
# Completed 2010-1
# Completed 2010-2
# Completed 2010-5
# Completed 2010-6
# Completed 2010-7
# Completed 2010-8
# Completed 2010-9
# Completed 2010-10
# Completed 2010-11
# Completed 2010-12
# Completed 2011-1
# Completed 2011-2
# Completed 2011-3
# Completed 2011-4
# Completed 2011-5
# Completed 2011-6
# Completed 2011-7
# Completed 2011-8
# Completed 2011-9
# Completed 2011-10
# Completed 2011-11
# Completed 2012-1
# Completed 2012-3
# Completed 2012-4
# Completed 2012-5
# Completed 2012-6
# Completed 2012-7
# Completed 2012-8
# Completed 2012-9
# Completed 2012-10
# Completed 2012-11
# Completed 2012-12
# Completed 2013-1
# Completed 2013-4
# Completed 2013-5
# Completed 2013-6
# Completed 2013-7
# Completed 2013-8
# Completed 2013-9
# Completed 2013-10
# Completed 2013-11
# Completed 2013-12
# Completed 2014-1
# Completed 2014-2
# Completed 2014-3
# Completed 2014-4
# Completed 2014-5
# Completed 2014-6
# Completed 2014-7
# Completed 2014-9
# Completed 2014-10
# Completed 2014-11
# Completed 2014-12
# Completed 2015-1
# Completed 2015-2
# Completed 2015-3
# Completed 2015-4
# Completed 2015-5
# Completed 2015-6
# Completed 2015-7
# Completed 2015-8
# Completed 2015-9
# Completed 2015-10
# Completed 2015-11
# Completed 2015-12
# Completed 2016-1
# Completed 2016-2
# Completed 2016-3
# Completed 2016-4
# Completed 2016-5
# Completed 2016-6
# Completed 2016-7
# Completed 2016-8
# Completed 2016-9
# Completed 2016-10
# Completed 2016-11
# Completed 2016-12
# Completed 2017-1
# Completed 2017-2
# Completed 2017-3
# Completed 2017-4
# Completed 2017-5
# Completed 2017-6
# Completed 2017-7
# Completed 2017-8
# Completed 2017-9
# Completed 2017-10
# Completed 2017-11
# Completed 2017-12
# Completed 2018-1
# Completed 2018-2
# Completed 2018-3
# Completed 2018-4
# Completed 2018-5
# Completed 2018-6
# Completed 2018-7
# Completed 2018-8
# Completed 2018-9
# Completed 2018-10
# Completed 2018-11
# Completed 2018-12
# Completed 2019-1
# Completed 2019-3
# Completed 2019-4
# Completed 2019-5
# Completed 2019-6
# Completed 2019-7
# Completed 2019-8
# Completed 2019-9
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-55-ce40ba9c7f4c> in <module>
# ----> 1 data = merge_news_price(df)
#
# <ipython-input-54-121183090e4c> in merge_news_price(df)
#      10                 pass
#      11
# ---> 12     all_news = pd.concat([df, all_news],join='inner', axis=1)
#      13
#      14     return all_news
#
# ~/anaconda3/envs/py3k/lib/python3.7/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     227                        verify_integrity=verify_integrity,
#     228                        copy=copy, sort=sort)
# --> 229     return op.get_result()
#     230
#     231
#
# ~/anaconda3/envs/py3k/lib/python3.7/site-packages/pandas/core/reshape/concat.py in get_result(self)
#     424             new_data = concatenate_block_managers(
#     425                 mgrs_indexers, self.new_axes, concat_axis=self.axis,
# --> 426                 copy=self.copy)
#     427             if not self.copy:
#     428                 new_data._consolidate_inplace()
#
# ~/anaconda3/envs/py3k/lib/python3.7/site-packages/pandas/core/internals/managers.py in concatenate_block_managers(mgrs_indexers, axes, concat_axis, copy)
#    2063         blocks.append(b)
#    2064
# -> 2065     return BlockManager(blocks, axes)
#
# ~/anaconda3/envs/py3k/lib/python3.7/site-packages/pandas/core/internals/managers.py in __init__(self, blocks, axes, do_integrity_check)
#     112
#     113         if do_integrity_check:
# --> 114             self._verify_integrity()
#     115
#     116         self._consolidate_check()
#
# ~/anaconda3/envs/py3k/lib/python3.7/site-packages/pandas/core/internals/managers.py in _verify_integrity(self)
#     309         for block in self.blocks:
#     310             if block._verify_integrity and block.shape[1:] != mgr_shape[1:]:
# --> 311                 construction_error(tot_items, block.shape[1:], self.axes)
#     312         if len(self.items) != tot_items:
#     313             raise AssertionError('Number of manager items must equal union of '
#
# ~/anaconda3/envs/py3k/lib/python3.7/site-packages/pandas/core/internals/managers.py in construction_error(tot_items, block_shape, axes, e)
#    1689         raise ValueError("Empty data passed with indices specified.")
#    1690     raise ValueError("Shape of passed values is {0}, indices imply {1}".format(
# -> 1691         passed, implied))
#    1692
#    1693
#
# ValueError: Shape of passed values is (4228, 9), indices imply (4220, 9)

# %%
data
# Out:
#                                                          News
# 2000-01-01  A Generation's Anthem: 'Smells Like Teen Press...
# 2000-01-02  Q & A/Christopher Wigren; Making a Job of Pres...
# 2000-01-03  Looking Back to Move ForwardA Touch of Spring ...
# 2000-01-04  No Bones About ItCarroll and Rhodes Are Out, a...
# 2000-01-05  Climate ControlWith Mild Winter, Snow Business...
# 2000-01-06  Calling All UnitsLarry Bearnarth, 58, the Best...
# 2000-01-07  Nature in a Flick of the EyeDefense Chief Pled...
# 2000-01-08  Florida Passes Bill to Quicken Execution PaceB...
# 2000-01-09  Despite Expectations, Magic Is Doing WellWriti...
# 2000-01-10  International Custody BattlePaid Notice: Death...
# 2000-01-11  Plagued by PovertyTHE MARKETS: CURRENCIESBring...
# 2000-01-12  When Things Fall ApartNot-So-Fickle Pinot Noir...
# 2000-01-13  Turning Some Things Old into Something NewSupr...
